# %% [markdown]
# <a href="https://colab.research.google.com/github/fqhkhwrzm/sanbercode/blob/main/Tugas_Hari_2_Pekan_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2>Soal 1:</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note: warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
# code here
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, cos, label='Cos x', linestyle='solid', color='red')
ax.plot(x, cos3, label='3 Cos x', linestyle='dashed', color='green')
ax.plot(x, sin, label='Sin(x-90', linestyle='dashdot', color='blue')
ax.plot(x, sin2, label='2 Sin x', linestyle='none', marker='x', color='orange')
plt.legend(loc='center')

ax.set_xlabel('X-Axis Label')
ax.set_ylabel('Y-Axis Label')
ax.set_title('Grafik Cos Sin')

plt.show()

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XRcfWyiWLDmriw7s7U4fTn5Gs6s2qf5o)
